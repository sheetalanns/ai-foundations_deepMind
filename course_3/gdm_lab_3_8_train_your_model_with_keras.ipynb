# %% [markdown]
# > <p><small><small>This Notebook is made available subject to the licence and terms set out in the <a href = "http://www.github.com/google-deepmind/ai-foundations">AI Research Foundations Github README file</a>.

# %% [markdown]
# <img src="https://storage.googleapis.com/dm-educational/assets/ai_foundations/GDM-Labs-banner-image-C3-white-bg.png">

# %% [markdown]
# # Lab: Train Your Model with Keras
#
# <a href='https://colab.research.google.com/github/google-deepmind/ai-foundations/blob/master/course_3/gdm_lab_3_8_train_your_model_with_keras.ipynb'
# target='_parent'><img src='https://colab.research.google.com/assets/colab-badge.svg' alt='Open In Colab'/></a>
#
# Train a neural network model using optimizers implemented in Keras.
#
# 25 minutes

# %% [markdown]
# ## Overview
#
# In the previous article, you have learned how stochastic gradient descent (SGD) can be used to train a neural network model. In this lab, you will put that knowledge into practice and explore how you can use the SGD-based optimizer **Adam** to train Keras models.

# %% [markdown]
# ### What you will learn:
#
# By the end of this lab, you will understand:
#
# * How you can train any Keras model, independent of its architecture.
# * The role of the optimizer and loss function and how they can be combined to train a model.

# %% [markdown]
# ### Tasks
#
# As in the previous labs, you will work with a dataset of prompt embeddings. The goal is to build a classifier that predicts the next word ("food" or "water") from the prompt embedding.
#
# **In this lab, you will**:
# * Load the dataset.
# * Define a two-layer neural network model using Keras.
# * Train the model using Keras implementations of the loss function, the Adam optimizer, and the training loop.
#
# All of these steps are described in detail in the following sections.

# %% [markdown]
# ## How to use Google Colaboratory (Colab)

# %% [markdown]
# Google Colaboratory (also known as Google Colab) is a platform that allows you to run Python code in your browser. The code is written in *cells* that are executed on a remote server.
#
# To run a cell, hover over a cell and click on the `run` button to its left. The run button is the circle with the triangle (▶). Alternatively, you can also click on a cell and use the keyboard combination Ctrl+Return (or ⌘+Return if you are using a Mac).
#
# To try this out, run the following cell. This should print today's day of the week below it.

# %%
from datetime import datetime

print(f"Today is {datetime.today():%A}.")
# Out:
# Today is Saturday.

# %% [markdown]
# Note that the order in which you run the cells matters. When you are working through a lab, make sure to always run all cells in order, otherwise the code might not work. If you take a break while working on a lab, Colab may disconnect you and in that case, you have to execute all cells again before  continuing your work. To make this easier, you can select the cell you are currently working on and then choose __Runtime → Run before__  from the menu above (or use the keyboard combination Ctrl/⌘ + F8). This will re-execute all cells before the current one.

# %% [markdown]
# ## Imports
#
# In this lab, you will primarily use the [`keras`](https://keras.io/) package for defining and training neural network models.
#
# Run the following cell to import all required packages.

# %%
import os # For adjusting Keras settings.
os.environ['KERAS_BACKEND'] = 'jax' # Set a parameter for Keras.

import jax.numpy as jnp # For defining and working with vectors and matrices.
import keras # For defining and training neural network models.
import pandas as pd # For displaying and loading data.

# %% [markdown]
# ## Load the data
#
# Run the following cell to download the dataset with 2-dimensional sentence embeddings. As in previous labs, the goal is to predict the next word from the words "food" (numeric label 1) and "water" (numeric label 2).

# %%
# Load data using pandas.
df = pd.read_csv("https://storage.googleapis.com/dm-educational/assets/ai_foundations/food-water-dataset.csv")

# Extract embeddings and labels.
X_train = jnp.array(df[["Embedding_dim_1", "Embedding_dim_2"]].values)
labels = df["Label"].values # Labels: "food" or "water".
# Convert labels to numeric values for training the model (food = 1, water = 0).
y_train = jnp.where(labels == "food", 1, 0)
df["Numeric label"] = y_train

# Print the loaded data for verification.
df.head(n=20)
# Out:
#                                                Prompt  Embedding_dim_1  \
# 0             Jide was hungry so she went looking for             0.27
# 1   The best part of the street fair was the incre...             1.06
# 2   He opened the refrigerator and it was full of ...             0.77
# 3   The main attraction at the festival was the am...             0.66
# 4                           The lion went hunting for             0.61
# 5            The farmers worked hard to grow a lot of             0.94
# 6   Her favourite part of visiting new places is t...             0.61
# 7            The toddlers made a huge mess with their             0.89
# 8           The market sells a lot of delicious fresh             0.64
# 9            My doctor advised me to avoid very fatty             0.71
# 10                   Stop playing a game of mouse and            -1.38
# 11           Jide was thirsty so she went looking for            -1.34
# 12        The first step in making tea is to boil the            -1.26
# 13  She stared at the reflection of the city light...            -0.72
# 14  He washed the mud from his boots with a bucket...            -1.36
# 15  To stay hydrated, it is recommended you drink ...            -1.53
# 16  A key sign of life on other planets that scien...            -0.69
# 17       The sound of rain comes from the dripping of            -0.99
# 18              The boat cut through the river's calm            -1.78
# 19            The well used to provide a lot of fresh            -0.75
#
#     Embedding_dim_2  Label  Numeric label
# 0              0.39   food              1
# 1              0.89   food              1
# 2              0.65   food              1
# 3              1.09   food              1
# 4              1.64   food              1
# 5              1.29   food              1
# 6              0.78   food              1
# 7              1.13   food              1
# 8              0.98   food              1
# 9              0.41   food              1
# 10            -1.12  water              0
# 11            -0.74  water              0
# 12            -0.90  water              0
# 13            -1.04  water              0
# 14            -0.98  water              0
# 15            -1.31  water              0
# 16            -1.00  water              0
# 17            -0.99  water              0
# 18            -1.00  water              0
# 19            -1.02  water              0

# %% [markdown]
# ## Define the neural network model
#
# The following cell implements a function `build_neural_network` for defining a two-layer neural network using Keras.
#
# The operations of the hidden layer are defined in
# ```python
# operations.append(keras.layers.Dense(hidden_dim, activation="relu"))
# ```
#
# and the operations of the output layer are defined in
# ```python
# operations.append(keras.layers.Dense(1, activation="sigmoid"))
# ```
#
# Reflect upon why this model is using a sigmoid activation function as the output layer? Could this be replaced with a SoftMax? When would this be useful?
#
# <br />
#
# ------
# > **ℹ️ Info: Combining layer operations**
# >
# >Note that for defining both layers, this code is combining two operations in one call here. When you implemented the MLP in one of the previous labs, you defined the computation of the dot product and the application of the activation function separately. However, as you rarely want to define a hidden layer without an activation function, Keras allows you to combine these two steps by passing the argument `activation` to the intialization of the `Dense` layer. You can find a list of available activation functions in the [Keras documentation](https://keras.io/api/layers/activations/).
# >
# ------
#
# <br />
#
# Inspect both the documentation of the `build_neural_network` function and its implementation to understand how it defines a neural network. Then run the following cell to define it so that you can use it later on.

# %%
def build_neural_network(hidden_dim: int = 10) -> keras.Model:
  """
  A function that initializes a two-layer neural network for binary
  classification, implemented in Keras. The hidden layer uses a ReLU activation
  function, and the output layer uses a sigmoid activation function.

  Args:
    hidden_dim: The dimension of the hidden layer.

  Returns:
    A keras.Model instance that implements the logistic regression model.
  """

  operations = []

  # Add the operations for a hidden layer with a ReLU activation function.
  operations.append(keras.layers.Dense(hidden_dim, activation="relu"))

  # Add the operations for an output layer with a sigmoid activation function.
  operations.append(keras.layers.Dense(1, activation="sigmoid"))

  # Construct a model such that inputs are passed sequentially through every
  # layer.
  model = keras.Sequential(operations)
  return model

# %% [markdown]
# ------
# > **ℹ️ Info: The ingredients for training a model**
# >
# >Most deep learning frameworks, including Keras, use a combination of three components to train a neural network model:
# >* The **loss function**: As you have already seen, the loss is a function of the current model weights, the current model predictions and the target labels in the training data. This is the function that you try to optimize during training. A lower value of this function means that the model is better at making predictions on examples in the training data.
# >* The **optimizer**: This component is responsible for updating the parameters (weights) of the model such that the loss decreases. In optimizers that you would use for training neural networks, the updating is based on the gradient of the loss function with respect to the training examples, as you observed in the discussion of the SGD algorithm. All optimizers have to be initialized with the `learning_rate` parameter. This parameter defines how big each update step should be.
# >* The **model**: This component defines which computations are needed to process the input. When you define a model using a deep learning framework such as Keras, this also automatically defines the necessary parameters for each layer. For example, when you define a layer using `Dense`, this also initializes the weights and the bias term for that layer.
# >
# ------

# %% [markdown]
# ## Coding activity 1: Define a loss function
#
# Before you can train a model, you have to define both the loss function and the optimizer. In almost all cases, you can use existing implementations for both of these components.

# %% [markdown]
# ------
# > **💻 Your task:**
# >
# > Your first task is to define the loss function. Remember that you are building a **binary classifier** that predicts the probability of the next word being "food" (class 1). As you have seen in the previous lab and articles, for such classifiers, you will use a binary cross-entropy loss. In Keras, loss functions are defined in the `keras.losses` module and the binary cross-entropy loss can be initialized using the following class:
# >
# >```python
# >keras.losses.BinaryCrossentropy()
# >```
# >
# >Define the binary cross-entropy loss in the cell below.
# ------

# %%
# Define the loss function.
loss_fn = keras.losses.BinaryCrossentropy()

# %% [markdown]
# ------
# > **ℹ️ Info: Other loss functions**
# >
# >If you were doing a multi-class classification task (i.e., a classifier that chooses between more than two classes), you would use a `keras.losses.CategoricalCrossentropy` or a `keras.losses.SparseCategoricalCrossentropy` loss function. You can find a list of all loss functions implemented in Keras in the [Keras documentation](https://keras.io/api/losses/).
# >
# ------

# %% [markdown]
# ## Coding activity 2: Define the optimizer
#
# As an optimizer, you will almost always use the Adam optimizer. This optimizer implements a more sophisticated version of the gradient update step than the regular SGD algorithm by adapting the step size depending on the shape of the loss function. In practice, this optimizer works very well for training neural networks.
#
# <br />
#
# ------
# > **💻 Your task:**
# >
# > Define the optimizer. The optimizer will compute the gradients and use them to update the parameters on each batch.
# >
# >In Keras, you can define the Adam optimizer as follows:
# >```python
# >keras.optimizers.Adam(learning_rate=<LEARNING RATE>)
# >```
# > If you want to apply weight decay, you can set its strength by adding the optional `weight_decay` parameter.
# >
# > Define this optimizer in the cell below. Use a learning rate of 0.01.
# ------

# %%
# Define the optimizer.
optimizer = keras.optimizers.Adam(learning_rate=0.01)

# %% [markdown]
# ## Putting it all together: The `compile` method
#
# Finally, once you have defined the loss function, and the optimizer, you can put all of these components together in preparation for training.
#
# First, you need to define your model. This should be an instance of the `keras.Model` class. In this activity, you will use the `build_neural_network` function from above to define an MLP.
#
# Then, to put everything together, you can use the `compile` method of the model. This method attaches the loss function and the optimizer to the model. You can also specify optional metrics, such as the accuracy. If you specify metrics, the result of applying the metric after each epoch will be printed as part of the training log.
#
# Run the following cell to define the model and combine it with the loss function, and the optimizer.

# %%
# Set a random seed for reproducibility.
keras.utils.set_random_seed(126)

# Define a model.
model = build_neural_network(hidden_dim = 10)

# Attach the loss function, the optimizer and metrics.
model.compile(loss=loss_fn, optimizer=optimizer, metrics=["accuracy"])

# %% [markdown]
# ## Coding activity 3: Train the model
#
# ------
# > **💻 Your task:**
# >
# > Train the model.
# >
# > To train the model, you can use the `model.fit()` method. This method takes the following arguments:
# >* `x`: The input of the training data (a JAX array, `X_train` in this case).
# >* `y`: the target values in the training data (a JAX array, `y_train` is this case).
# >* `epochs`: The number of epochs. This specifies how many times the model loops through all training examples.
# >* `batch_size` (optional): This specifies how many examples there should be in one mini-batch.
# >* `validation_data` (optional): A tuple `(X_val, y_val)` to compute the validation loss and accuracy after each epoch.
# >* `callbacks` (optional): A list of functions that should be executed at the end of each epoch. One useful function to include in this list is `keras.callbacks.EarlyStopping()` to implement early stopping.
# >
# >The function returns the training history that contains the loss and the accuracy after each epoch of training.
# >
# >In the following cell, implement training with the `fit` method. Train the model for 100 epochs with a mini-batch size of 8.
#
# ------

# %%
# Use the model.fit() method to train your model.
history = model.fit(
    x=X_train,
    y=y_train,
    epochs=200,
)
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.5000 - loss: 0.6609
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5000 - loss: 0.6230
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5500 - loss: 0.5875
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7500 - loss: 0.5539
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9000 - loss: 0.5218
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.4911
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.4623
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.4352
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.4101
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.3868
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3651
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.3447
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.3254
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.3070
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.2899
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2737
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.2584
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.2443
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2310
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.2185
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.2067
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.1958
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.1855
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1759
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.1668
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.1582
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1502
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.1426
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.1355
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.1287
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.1223
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.1163
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.1106
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.1053
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1002
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0953
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0908
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0864
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0823
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0784
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0747
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0712
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0679
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0647
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0617
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0588
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0561
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0535
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0511
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0488
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0466
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0445
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0426
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0407
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0389
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0372
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0357
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0342
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0327
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0314
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0301
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - accuracy: 1.0000 - loss: 0.0289
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0278
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0267
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0257
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0247
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0238
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0229
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0221
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0213
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0205
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0198
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0191
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0185
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0179
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0173
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0167
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0162
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0157
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0152
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0148
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0143
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0139
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0112
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0109
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0101
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0047
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 1.0000 - loss: 0.0022

# %% [markdown]
# Congratulations! You now know all the steps involved in training neural network models with Keras. In the future, come back to this notebook if you need to train a Keras model to revise the steps.
#
# You can also experiment with changing the model, or changing the parameters of the optimizer, or the training procedure to observe how the training process changes.

# %% [markdown]
# ## Summary
#
# In this activity, you trained a simple neural network using the Adam optimizer. You learned how the loss function, the optimizer and the model are combined in Keras to allow you to train any neural network model. You also learned where you can set hyperparameters such as the learning rate, the weight decay strength, or the number of epochs.
#
# In future courses, you will apply this knowledge to train and fine-tune language models. While those models will be more complicated than the MLP that you have been working with here, all the same principles will apply.

# %% [markdown]
# ## Solutions
#
#
# The following cells provide reference solutions to the coding activities in this notebook. If you really get stuck after trying to solve the activities yourself, you may want to consult these solutions.
#
#
# It is recommended that you *only* look at the solutions after you have tried to solve the activities *multiple times*. The best way to learn challenging concepts in computer science and artificial intelligence is to debug your code piece-by-piece until it works, rather than copying existing solutions.
#
#
# If you feel stuck, you may want to first try to debug your code. For example, by adding additional print statements to see what your code is doing at every step. This will provide you with a much deeper understanding of the code and the materials. It will also provide you with practice on how to solve challenging coding problems beyond this course.
#
#
# To view the solutions for an activity, click on the arrow to the left of the activity name. If you consult the solutions, do not copy and paste them into the cells above. Instead, look at them, and type them manually into the cell. This will help you understand where you went wrong.

# %% [markdown]
# ### Coding Activity 1

# %%
# Copy this into the cell above.
loss_fn = keras.losses.BinaryCrossentropy()

# %% [markdown]
# ### Coding Activity 2

# %%
# Copy this into the cell above.
optimizer = keras.optimizers.Adam(learning_rate=0.01)

# %% [markdown]
# ### Coding Activity 3

# %%
# Copy this into the cell above.
history = model.fit(x=X_train, y=y_train, epochs=10, batch_size=8)
